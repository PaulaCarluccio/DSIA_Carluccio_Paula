# %% [markdown]
# # TP03 – Python Librerías

# %% [markdown]
# Carluccio, Paula

# %% [markdown]
# ## Ejercicio 1 – Importación de librerías

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

datos = np.array([5, 8, 420, 2567, 7520000])
print(datos)
# Out:
# [      5       8     420    2567 7520000]

# %% [markdown]
# ## Ejercicio 2 – Dataset simple con Pandas

# %%
datos = {
    "estudiante": ["Ana", "Juan", "Carla", "Pedro", "Lucia"],
    "nota": [8, 6, 9, 5, 7]
}

df = pd.DataFrame(datos)

#Mostrar el DataFrame
print(df)

# Calcular el promedio
print("\nPromedio de las notas:", df["nota"].mean())

# Mostrar la nota máxima
print("Nota máxima:", df["nota"].max())

# Mostrar la nota mínima
print("Nota mínima:", df["nota"].min())
# Out:
#   estudiante  nota
# 0        Ana     8
# 1       Juan     6
# 2      Carla     9
# 3      Pedro     5
# 4      Lucia     7
#
# Promedio de las notas: 7.0
# Nota máxima: 9
# Nota mínima: 5

# %% [markdown]
# ## Ejercicio 3 – Criterio de selección de herramientas

# %% [markdown]
# Leer un archivo CSV con datos de encuestas
# Crear un gráfico de distribución de datos
# Realizar un modelo de Machine Learning
# Trabajar con operaciones matemáticas sobre matrices
# Escribir la librería elegida y una breve justificación\.

# %% [markdown]
# Pandas → porque sirve para leer archivos CSV y trabajar con datos organizados en tablas\.
# Matplotlib → porque permite crear gráficos para visualizar y entender mejor los datos\.
# Scikit\-learn → porque se utiliza para crear, entrenar y evaluar modelos de Machine Learning\.
# NumPy → porque permite trabajar con matrices y realizar operaciones matemáticas\.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6ff632f8-7a92-48ed-b4f8-3f73738bfc13' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
