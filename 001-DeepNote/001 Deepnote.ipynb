# %% [markdown]
# # TP01 \- Deepnote Carluccio Paula

# %% [markdown]
# Soy Paula, trabajo en QA Automation y me interesa seguir aprendiendo sobre tecnología y análisis de datos\. En mi trabajo me dedico a automatizar pruebas y verificar que los sistemas funcionen correctamente\. Espero que la materia DSIA me ayude a comprender mejor la ciencia de datos y la inteligencia artificial, y a conocer herramientas que pueda aplicar tanto en mi trabajo como en futuros proyectos\.

# %%
print("Mi primer notebook en Deepnote")
# Out:
# Mi primer notebook en Deepnote

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6ff632f8-7a92-48ed-b4f8-3f73738bfc13' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
